# %%
from PIL import Image
import os
from tqdm.notebook import tqdm
import concurrent.futures

# 입력 폴더와 출력 폴더 설정
input_folder = "trainall/valid_img_anno/"
output_folder = "background_dataset/valid_img_anno"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내의 모든 파일 목록 가져오기
file_list = os.listdir(input_folder)

def process_image(filename):
    # 파일 경로 생성
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    try:
        # 이미지 열기
        img = Image.open(input_path)

        # 픽셀 값 255를 12로 변환
        img = img.point(lambda p: p if p != 255 else 12)

        # 변환된 이미지 저장
        img.save(output_path)
        #print(f"{input_path} 변환 완료")

    except Exception as e:
        print(f"{input_path} 변환 중 오류 발생: {str(e)}")

# 작업을 병렬로 처리하기 위해 ThreadPoolExecutor 사용
with concurrent.futures.ThreadPoolExecutor() as executor:
    list(tqdm(executor.map(process_image, file_list), total=len(file_list)))
# Out:
# trainall/valid_img_anno/TRAIN_TARGET_2603.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2602.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2600.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2601.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2612.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2607.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2608.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2609.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2604.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2610.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2613.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2614.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2606.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2605.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2617.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2615.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2611.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2616.png 변환 완료
#   0%|          | 0/789 [00:00<?, ?it/s]
# trainall/valid_img_anno/TRAIN_TARGET_2620.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2619.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2625.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2624.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2622.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2626.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2621.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2623.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2628.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2629.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2618.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2631.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2630.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2627.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2635.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2634.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2633.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2632.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2641.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2636.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2644.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2643.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2646.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2637.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2645.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2639.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2649.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2640.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2642.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2648.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2638.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2651.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2650.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2652.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2653.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2654.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2658.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2647.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2656.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2659.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2657.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2661.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2662.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2663.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2655.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2665.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2666.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2667.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2660.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2670.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2664.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2668.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2672.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2673.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2671.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2669.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2677.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2676.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2679.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2675.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2680.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2678.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2682.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2685.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2686.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2683.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2674.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2687.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2684.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2688.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2681.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2689.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2693.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2691.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2692.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2696.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2695.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2694.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2698.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2700.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2690.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2702.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2701.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2703.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2699.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2697.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2705.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2707.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2709.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2706.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2704.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2711.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2712.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2708.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2713.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2715.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2716.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2714.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2718.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2723.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2710.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2724.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2721.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2720.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2719.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2722.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2717.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2726.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2729.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2730.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2731.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2732.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2735.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2734.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2725.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2733.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2736.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2737.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2728.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2738.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2739.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2727.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2743.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2744.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2741.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2742.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2745.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2748.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2747.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2740.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2750.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2746.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2754.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2751.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2753.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2752.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2749.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2757.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2755.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2758.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2760.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2759.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2761.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2762.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2764.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2756.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2767.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2765.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2769.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2766.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2772.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2773.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2774.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2776.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2770.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2763.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2775.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2777.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2768.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2779.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2771.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2781.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2780.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2785.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2782.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2778.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2784.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2786.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2788.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2787.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2789.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2791.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2793.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2792.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2783.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2790.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2795.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2797.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2794.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2799.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2801.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2796.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2802.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2798.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2800.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2803.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2805.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2804.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2807.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2808.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2806.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2809.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2811.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2812.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2810.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2815.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2813.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2814.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2816.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2817.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2820.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2819.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2822.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2825.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2824.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2818.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2828.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2821.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2827.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2830.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2831.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2823.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_2834.png 변환 완료
# trainall/valid_img_anno/TRAIN_TARGET_
png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_267.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_261.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_264.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_265.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_269.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_268.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_270.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_271.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_272.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_275.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_277.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_276.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_273.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_274.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_279.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_280.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_281.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_282.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_283.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_286.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_288.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_290.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_285.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_287.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_289.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_291.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_278.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_293.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_284.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_292.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_301.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_294.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_295.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_300.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_296.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_297.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_298.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_299.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_306.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_302.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_303.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_304.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_305.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_309.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_308.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_307.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_310.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_311.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_313.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_314.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_312.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_315.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_321.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_318.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_320.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_319.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_323.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_324.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_316.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_322.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_325.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_317.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_326.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_330.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_329.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_328.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_331.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_332.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_327.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_334.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_336.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_338.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_337.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_335.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_340.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_339.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_341.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_343.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_345.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_333.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_344.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_347.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_348.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_350.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_346.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_351.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_349.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_353.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_342.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_352.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_354.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_355.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_357.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_358.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_356.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_359.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_362.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_360.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_363.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_361.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_364.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_367.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_370.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_368.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_366.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_369.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_372.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_373.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_365.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_375.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_377.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_371.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_376.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_378.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_382.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_374.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_381.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_379.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_383.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_380.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_385.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_387.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_388.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_386.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_384.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_389.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_392.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_391.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_390.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_393.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_394.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_395.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_396.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_398.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_397.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_400.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_399.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_402.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_401.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_405.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_404.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_403.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_406.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_407.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_408.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_410.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_412.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_415.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_413.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_414.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_417.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_409.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_424.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_421.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_425.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_427.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_416.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_430.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_419.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_428.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_418.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_423.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_429.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_431.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_422.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_434.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_433.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_420.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_432.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_436.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_437.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_426.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_435.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_438.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_439.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_442.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_441.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_443.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_444.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_446.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_440.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_447.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_448.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_449.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_445.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_450.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_453.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_451.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_452.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_456.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_454.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_455.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_461.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_460.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_457.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_458.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_459.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_411.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_462.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_464.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_465.png 변환 완료
# trainall/valid_img_anno/VALID_SOURCE_463.png 변환 완료

# %%
pwd
# Out:
# 'C:\\Users\\ADMIN\\Projects\\JBK\\mmseg_Data'

# %%
# %rm -r background_datset
# Out:
# UsageError: Line magic function `%rm` not found.

# %% [markdown]
# # 13 class dataset

# %%
from PIL import Image
import os
from tqdm.notebook import tqdm
import concurrent.futures

# 입력 폴더와 출력 폴더 설정
input_folder = "open/train_img"
output_folder = "13class_dataset/train_img"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내의 모든 파일 목록 가져오기
file_list = os.listdir(input_folder)

def process_image(filename):
    # 파일 경로 생성
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    try:
        # 이미지 열기
        img = Image.open(input_path)

        # 픽셀 값 255를 12로 변환
        #img = img.point(lambda p: p if p != 255 else 12)

        # 변환된 이미지 저장
        img.save(output_path)
        #print(f"{input_path} 변환 완료")

    except Exception as e:
        print(f"{input_path} 변환 중 오류 발생: {str(e)}")

# 작업을 병렬로 처리하기 위해 ThreadPoolExecutor 사용
with concurrent.futures.ThreadPoolExecutor() as executor:
    list(tqdm(executor.map(process_image, file_list), total=len(file_list)))
# Out:
# open/train_img\.ipynb_checkpoints 변환 중 오류 발생: [Errno 13] Permission denied: 'open/train_img\\.ipynb_checkpoints'
#   0%|          | 0/2195 [00:00<?, ?it/s]

# %%
from PIL import Image
import os
from tqdm.notebook import tqdm
import concurrent.futures

# 입력 폴더와 출력 폴더 설정
input_folder = "open/valid_img"
output_folder = "13class_dataset/valid_img"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내의 모든 파일 목록 가져오기
file_list = os.listdir(input_folder)

def process_image(filename):
    # 파일 경로 생성
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    try:
        # 이미지 열기
        img = Image.open(input_path)

        # 픽셀 값 255를 12로 변환
        #img = img.point(lambda p: p if p != 255 else 12)

        # 변환된 이미지 저장
        img.save(output_path)
        #print(f"{input_path} 변환 완료")

    except Exception as e:
        print(f"{input_path} 변환 중 오류 발생: {str(e)}")

# 작업을 병렬로 처리하기 위해 ThreadPoolExecutor 사용
with concurrent.futures.ThreadPoolExecutor() as executor:
    list(tqdm(executor.map(process_image, file_list), total=len(file_list)))
# Out:
#   0%|          | 0/466 [00:00<?, ?it/s]

# %%
from PIL import Image
import os
from tqdm.notebook import tqdm
import concurrent.futures

# 입력 폴더와 출력 폴더 설정
input_folder = "open/train_img_anno"
output_folder = "13class_dataset/train_img_anno"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내의 모든 파일 목록 가져오기
file_list = os.listdir(input_folder)

def process_image(filename):
    # 파일 경로 생성
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    try:
        # 이미지 열기
        img = Image.open(input_path)

        # 픽셀 값 255를 12로 변환
        img = img.point(lambda p: p if p != 255 else 12)

        # 변환된 이미지 저장
        img.save(output_path)
        #print(f"{input_path} 변환 완료")

    except Exception as e:
        print(f"{input_path} 변환 중 오류 발생: {str(e)}")

with concurrent.futures.ThreadPoolExecutor() as executor:
    list(tqdm(executor.map(process_image, file_list), total=len(file_list)))
# Out:
# open/train_img_anno\.ipynb_checkpoints 변환 중 오류 발생: [Errno 13] Permission denied: 'open/train_img_anno\\.ipynb_checkpoints'
#   0%|          | 0/2195 [00:00<?, ?it/s]

# %%
from PIL import Image
import os
from tqdm.notebook import tqdm
import concurrent.futures

# 입력 폴더와 출력 폴더 설정
input_folder = "open/valid_img_anno"
output_folder = "13class_dataset/valid_img_anno"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내의 모든 파일 목록 가져오기
file_list = os.listdir(input_folder)

def process_image(filename):
    # 파일 경로 생성
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    try:
        # 이미지 열기
        img = Image.open(input_path)

        # 픽셀 값 255를 12로 변환
        img = img.point(lambda p: p if p != 255 else 12)

        # 변환된 이미지 저장
        img.save(output_path)
        #print(f"{input_path} 변환 완료")

    except Exception as e:
        print(f"{input_path} 변환 중 오류 발생: {str(e)}")


with concurrent.futures.ThreadPoolExecutor() as executor:
    list(tqdm(executor.map(process_image, file_list), total=len(file_list)))
# Out:
#   0%|          | 0/466 [00:00<?, ?it/s]
